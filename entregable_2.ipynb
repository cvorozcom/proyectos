# %%
import pandas as pd
import numpy as np

# Configuración matplotlib
# ==============================================================================
plt.rcParams['image.cmap'] = "bwr"
#plt.rcParams['figure.dpi'] = "100"
plt.rcParams['savefig.bbox'] = "tight"
style.use('ggplot') or plt.style.use('ggplot')

# Configuración warnings
# ==============================================================================
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Importar archivos
#
# 1. **Importar el archivo con dos niveles superiores de la carpeta que contiene el archivo**
#  bd_1 = pd.read_csv("../clauo/marketing_campaign.csv")
#
# 2. **Importar el archivo desde la dirección completa**
#  bd_2 = pd.read_csv(filepath_or_buffer = "/Users/clauo/marketing_campaign.csv")
#
# 3. **Importar el archivo guardando la dirección en diferentes objetos**
#  mainpath = "/Users/clauo"
#  filename = "marketing_campaign.csv"
#  fullpath = os.path.join(mainpath,filename)
#  bd_3 = pd.read_csv(fullpath)

# %%
bd = pd.read_csv("../clauo/marketing_campaign.csv")

# %%
bd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 29 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   2240 non-null   int64
#  1   Year_Birth           2240 non-null   int64
#  2   Education            2240 non-null   object
#  3   Marital_Status       2240 non-null   object
#  4   Income               2216 non-null   float64
#  5   Kidhome              2240 non-null   int64
#  6   Teenhome             2240 non-null   int64
#  7   Dt_Customer          2240 non-null   object
#  8   Recency              2240 non-null   int64
#  9   MntWines             2240 non-null   int64
#  10  MntFruits            2240 non-null   int64
#  11  MntMeatProducts      2240 non-null   int64
#  12  MntFishProducts      2240 non-null   int64
#  13  MntSweetProducts     2240 non-null   int64
#  14  MntGoldProds         2240 non-null   int64
# ...

# %%
bd.describe()
# Out:
#                  ID   Year_Birth         Income      Kidhome     Teenhome  \
# count   2240.000000  2240.000000    2216.000000  2240.000000  2240.000000
# mean    5592.159821  1968.805804   52247.251354     0.444196     0.506250
# std     3246.662198    11.984069   25173.076661     0.538398     0.544538
# min        0.000000  1893.000000    1730.000000     0.000000     0.000000
# 25%     2828.250000  1959.000000   35303.000000     0.000000     0.000000
# 50%     5458.500000  1970.000000   51381.500000     0.000000     0.000000
# 75%     8427.750000  1977.000000   68522.000000     1.000000     1.000000
# max    11191.000000  1996.000000  666666.000000     2.000000     2.000000
#
#            Recency     MntWines    MntFruits  MntMeatProducts  \
# count  2240.000000  2240.000000  2240.000000      2240.000000
# mean     49.109375   303.935714    26.302232       166.950000
# std      28.962453   336.597393    39.773434       225.715373
# ...

# %%
bd.corr()
# Out:
#                            ID  Year_Birth    Income   Kidhome  Teenhome  \
# ID                   1.000000    0.000028  0.013095  0.002406 -0.002580
# Year_Birth           0.000028    1.000000 -0.161791  0.230176 -0.352111
# Income               0.013095   -0.161791  1.000000 -0.428669  0.019133
# Kidhome              0.002406    0.230176 -0.428669  1.000000 -0.036133
# Teenhome            -0.002580   -0.352111  0.019133 -0.036133  1.000000
# Recency             -0.046524   -0.019871 -0.003970  0.008827  0.016198
# MntWines            -0.022878   -0.157773  0.578650 -0.496297  0.004846
# MntFruits            0.004600   -0.017917  0.430842 -0.372581 -0.176764
# MntMeatProducts     -0.004437   -0.030872  0.584633 -0.437129 -0.261160
# MntFishProducts     -0.024475   -0.041625  0.438871 -0.387644 -0.204187
# MntSweetProducts    -0.007642   -0.018133  0.440744 -0.370673 -0.162475
# MntGoldProds        -0.013438   -0.061818  0.325916 -0.349595 -0.021725
# ...

# %%
ingreso = bd.Income
ingreso
# Out:
# 0       58138.0
# 1       46344.0
# 2       71613.0
# 3       26646.0
# 4       58293.0
#          ...
# 2235    61223.0
# 2236    64014.0
# 2237    56981.0
# 2238    69245.0
# 2239    52869.0
# Name: Income, Length: 2240, dtype: float64

# %%
ingreso_prom = ingreso.mean()
ingreso_prom
# Out:
# 52247.25135379061

# %%
bd.plot.scatter(x="NumWebVisitsMonth",y="NumWebPurchases")
plt.title('Relación entre cantidad de visitas al sitio web y cantidad compras online', loc = "left", fontdict = {'fontsize':14, 'fontweight':'bold', 'color':'tab:blue'})
plt.show()

# %%
nivel_escolaridad = bd.Education.value_counts()

# %%
nivel_escolaridad
# Out:
# Graduation    1127
# PhD            486
# Master         370
# 2n Cycle       203
# Basic           54
# Name: Education, dtype: int64

# %%
nivel_escolaridad.plot.pie(autopct='%1.1f%%')
plt.title('Porcentaje Clientes por Nivel de Escolaridad', loc = "left", fontdict = {'fontsize':14, 'fontweight':'bold', 'color':'tab:blue'})
# Out:
# Text(0.0, 1.0, 'Porcentaje Clientes por Nivel de Escolaridad')

# %%
visitas_sitio_web = bd.NumWebVisitsMonth.value_counts()

# %%
plt.title('Cantidad de visitas al sitio web en el último mes', loc = "left", fontdict = {'fontsize':14, 'fontweight':'bold', 'color':'tab:blue'})
plt.xlabel("Cantidad de visitas")
plt.ylabel("Frecuencia")
visitas_sitio_web.plot.hist()
# Out:
# <AxesSubplot:title={'left':'Cantidad de visitas al sitio web en el último mes'}, xlabel='Cantidad de visitas', ylabel='Frequency'>

# %%
compras_online = bd.NumWebPurchases.value_counts()

# %%
compras_online
# Out:
# 2     373
# 1     354
# 3     336
# 4     280
# 5     220
# 6     205
# 7     155
# 8     102
# 9      75
# 0      49
# 11     44
# 10     43
# 27      2
# 23      1
# 25      1
# Name: NumWebPurchases, dtype: int64

# %%
compras_fisicas = bd.NumStorePurchases.value_counts()
compras_fisicas
# Out:
# 3     490
# 4     323
# 2     223
# 5     212
# 6     178
# 8     149
# 7     143
# 10    125
# 9     106
# 12    105
# 13     83
# 11     81
# 0      15
# 1       7
# Name: NumStorePurchases, dtype: int64

# %%
quejas = bd.Complain.value_counts()
quejas
# Out:
# 0    2219
# 1      21
# Name: Complain, dtype: int64

# %%
quejas = quejas.sort_values(ascending=True) #También se puede ordenar por indice sort_index

# %%
plt.title('Cantidad de quejas en los últimos 2 años', loc = "left", fontdict = {'fontsize':14, 'fontweight':'bold', 'color':'tab:blue'})
quejas.plot.barh()
# Out:
# <AxesSubplot:title={'left':'Cantidad de quejas en los últimos 2 años'}>

# %%
visitas_mes = bd.NumWebVisitsMonth.value_counts()

# %%
fig, ax = plt.subplots()
ax.set_title('Cantidad de visitas último mes', loc = "left", fontdict = {'fontsize':14, 'fontweight':'bold', 'color':'tab:blue'})
visitas_mes.plot.hist()
plt.show()
